# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
data_source='homeprice.xlsx'

# %%
df=pd.read_excel(data_source)
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df['area']
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# Name: area, dtype: int64

# %%
 df[df['area']==3600]['price']
# Out:
# 3    680000
# Name: price, dtype: int64

# %%
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US)')
plt.scatter(df.area,df.price,color='red',marker='*')

# %%
plt.plot(df.area,df.price,color='red')

# %%
plt.plot(df['area'],df['price'])

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df['price'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
reg.predict(3300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-ad5a8409ff75> in <module>
# ----> 1 reg.predict(3300)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
df.plot(x='area',y='price',kind='scatter')
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#            area     price
# area   1.000000  0.978994
# price  0.978994  1.000000

# %%
data1=pd.DataFrame(df['area'])
data2=pd.DataFrame(df['price'])

# %%
data1
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
data2
# Out:
#     price
# 0  550000
# 1  565000
# 2  610000
# 3  680000
# 4  725000

# %%
lm=linear_model.LinearRegression()
model=lm.fit(data1,data2)

# %%
model.coef_
# Out:
# array([[135.78767123]])

# %%
model.intercept_
# Out:
# array([180616.43835616])

# %%
model.score(data1,data2)
# Out:
# 0.9584301138199486

# %%
area_new=3300
price_predict=model.predict(area_new)
price_predict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-b9865415ac1f> in <module>
#       1 area_new=3300
# ----> 2 price_predict=model.predict(area_new)
#       3 price_predict
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ...
